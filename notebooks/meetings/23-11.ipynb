# %%
from IPython.display import IFrame, display
import os
os.chdir('../../')
print(os.getcwd())
# Out:
# /home/boesch/island_semester_project/notebooks/meetings
# /home/boesch/island_semester_project

# %% [markdown]
# # Stimuli Effect

# %%
report_path = "reports/glm/per_trial/sub-P10/sub-P10_smooth_None_bonferroni_ContrastType.PER_TRIAL_glm_report.html"

IFrame(report_path, width="100%", height=100)
# Out:
#         <iframe
#             width="100%"
#             height="100"
#             src="reports/glm/per_trial/sub-P10/sub-P10_smooth_None_bonferroni_ContrastType.PER_TRIAL_glm_report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

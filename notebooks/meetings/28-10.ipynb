# %% [markdown]
# # RSA Analysis
# ## Deuker et al. Reproduction

# %% [markdown]
# ### Deuker et al.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### My Results

# %% [markdown]
# Temporal RDM ↔ RSA (full) (N=28):
#   Mean ρ = 0.0055 ± 0.0079 (SEM)
#   Mean p = 0.4505
#
# Group-level permutation test (spatial): p = 0.1495, observed mean Z = -0.4284
#
# Group-level permutation test (temporal): p = 0.4357, observed mean Z = 0.1849
#
# Spatial RDM  ↔ RSA (full) (N=28):
#   Mean ρ = -0.0136 ± 0.0103 (SEM)
#   Mean p = 0.3883
#
# Spatial  RDM ↔ RSA (median split):
#   Low-dist mean ρ = -0.0182 ± 0.0103 (SEM)
#   High-dist mean ρ = 0.0099 ± 0.0132 (SEM)

# %% [markdown]
# ![group_rsa_barplot.png](attachment:group_rsa_barplot.png)
#  ![group_rsa_zvalue_histograms.png](attachment:group_rsa_zvalue_histograms.png)

# %% [markdown]
# Opposite effect observed although not significant so...

# %% [markdown]
# ## Questions regarding deuker et al. methods
# ### Comparing pearson values (an increase in pearson values, post-pre) to distances ?
# - The brain has two ways of encoding information that are differentiable with pearson's coefficient -> positive or negative correlation with no information (random) with coefficient 0
# - If we say that distance is positively correlated to pearson's values it means that when an image pair is more distant than another one it also has a higher pearson value. However This could mean two completely different things :
#   Case 1 : We have two images very close with complete anti correlation -1 and two images very far with correlation 0 -> Images that are close together share information, far are completely random
#   Case 2 : We have two images very close with complete anti correlation 0 and two images very far with correlation 1
#   -> Images that are far from one another share information, close are completely random
# -> linear scale of similarity debatable ?
# #### use euclidean distance instead ?
# Temporal RDM ↔ RSA (full) (N=28):
#   Mean ρ = 0.0111 ± 0.0131 (SEM)
#   Mean p = 0.2806
#
# Group-level permutation test (spatial): p = 0.9188, observed mean Z = 0.0506
#
# Group-level permutation test (temporal): p = 0.3493, observed mean Z = 0.3167
#
# Spatial RDM  ↔ RSA (full) (N=28):
#   Mean ρ = 0.0072 ± 0.0165 (SEM)
#   Mean p = 0.2929
#
# Spatial  RDM ↔ RSA (median split):
#   Low-dist mean ρ = -0.0240 ± 0.0145 (SEM)
#   High-dist mean ρ = 0.0203 ± 0.0228 (SEM)

# %% [markdown]
# ![group_rsa_zvalue_histograms.png](attachment:group_rsa_zvalue_histograms.png)
# ![group_rsa_barplot.png](attachment:group_rsa_barplot.png)

# %% [markdown]
# We seem here to have same effect over all (since we go from similarity to dissimilarity) but opposite effect when using median split. Still nothing significant

# %% [markdown]
# #### Separate Positive and Negative effects ?
# Temporal RDM ↔ RSA (positive) (N=28):
#   Mean ρ = 0.0034 ± 0.0086 (SEM)
#   Mean p = 0.4293
#
# Spatial RDM  ↔ RSA (positive) (N=28):
#   Mean ρ = -0.0160 ± 0.0095 (SEM)
#   Mean p = 0.3818
#
# Temporal RDM ↔ RSA (negative) (N=28):
#   Mean ρ = 0.0042 ± 0.0072 (SEM)
#   Mean p = 0.5268
#
# Spatial RDM  ↔ RSA (negative) (N=28):
#   Mean ρ = -0.0118 ± 0.0090 (SEM)
#   Mean p = 0.4329

# %% [markdown]
# ![group_rsa_pos_neg_barplot.png](attachment:group_rsa_pos_neg_barplot.png)

# %% [markdown]
# The effect seems to be indeed unidirectional and not bidirectional. The effect is the same from -1 0 and from 0 to 1.

# %% [markdown]
# ### Spearman correlation ?
# - Pearson values seems to follow a null distribution. The meaning can thus only emerge from the organization of those values and its correlation to distance.
#
# - When taking the rank we give as much significanc to a difference of 0.00001 and 0.0001 than -0.04 to 0.04.
#
# - Judgements Distances are not normally distributed or from a null distribution

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Why use permutation and not just the p-value from correlation ?
# ### Random Contrasts

# %%
from IPython.display import HTML
import os
os.chdir('../../')
with open("notebooks/images/28-10/sub-P10_smooth_5_fdr_random__glm_report.html", "r") as f:
    html_content = f.read()
print("GLM Report for sub10 level with random contrast - FDR correction")
HTML(f"""
<div style="width:1000px; height:600px; overflow:auto; border:1px solid #ccc;">
{html_content}
</div>
""")
# Out:
# GLM Report for sub10 level with random contrast - FDR correction
# <div style="width:1000px; height:600px; overflow:auto; border:1px solid #ccc;">
# <!doctype html>
# <html lang="en">
#   <head>
#     <title>Nilearn - Statistical Report - First Level Model</title>
#
#     <link
#       rel="icon"
#       type="image/x-icon"
#       href="https://raw.githubusercontent.com/nilearn/nilearn/main/doc/logos/favicon.ico"
#     />
#
#     <meta
#       name="viewport"
#       content="width = device-width, initial-scale = 1"
#       charset="UTF-8"
#     />
#
#     <style type="text/css">
#       html {
#   font-family: sans-serif;
# }
#
# main {
#   margin: 4px 8px 4px 8px;
#   display: flex;
#   justify-content: center;
# }
#
# body footer {
#   padding: 0px 32px 0px 32px;
#   display: flex;
#   justify-content: center;
#   text-align: center;
# }
#
#     </style>
#   </head>
#
#   <body>
#     <main><!-- CSS for the report -->
#
# <link
#   rel="stylesheet"
# ...

# %% [markdown]
# ### Events file Analysis
# ### Confounders ? Which one to use I used only the main one without derivatives etc...
#
# ==============================================================================================================================================

# %% [markdown]
# # Presentation Plan
#
# ## Small Reintroduction
# ### Focus on memory task -> judgment distances
# ### Reminder of RSA
# ## Further Analysis of Old vs. New with derivatives
# ## Calculation of Judgment distances
# ### Confidence Analysis
# ### Selection of only True Postive
# ## Reproduction Deuker et al results
# ## Other approaches
# ### Euclidean distance
# ### Separation of positive negative
# ## Conclusions
# ## Future Directions

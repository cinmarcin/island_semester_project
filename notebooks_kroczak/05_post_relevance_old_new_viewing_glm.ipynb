# %% [markdown]
# # 05 — POST relevance old/new viewing GLM
#
# This notebook tests whether POST-viewing responses differ between:
#
# - goal-relevant old images,
# - goal-irrelevant old images,
# - new control images.
#
# It is a **POST-only** analysis, so the first-level GLM contains a single viewing run from the POST session. This keeps the design simple and directly matches the supervisor's requested contrast: **POST Relevant vs Irrelevant vs New**.
#
# The notebook is restart-safe:
#
# - first-level maps are saved immediately;
# - `RUN_FIRST_LEVEL=False` loads/verifies existing maps;
# - `OVERWRITE_FIRST_LEVEL=False` runs only missing subjects;
# - all figures use the common high-resolution mean T1w anatomical background from Notebook 00.

# %%
# ============================================================
# 1. Setup
# ============================================================

from pathlib import Path
import sys
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display
from nilearn.image import load_img

pd.set_option("display.max_columns", 160)
pd.set_option("display.max_colwidth", 160)

PROJECT_ROOT = Path("/media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project")
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from island_glm.paths import ProjectPaths, make_analysis_dirs
from island_glm.common import load_common_inputs, get_pre_post_subjects
from island_glm.events import (
    save_post_relevance_subject_events,
    build_post_relevance_event_qc,
    make_post_relevance_events,
)
from island_glm.contrasts import (
    make_post_relevance_old_new_contrasts,
    contrast_specs_to_table,
)
from island_glm.first_level import run_post_relevance_first_level_subject
from island_glm.second_level import (
    first_level_map_path,
    verify_first_level_maps,
    run_second_level_all_contrasts,
    threshold_group_maps,
    make_cluster_tables,
)
from island_glm.reporting import label_cluster_table
from island_glm.plotting import plot_group_stat_map, make_interactive_view

ANALYSIS_NAME = "post_relevance_old_new_viewing_glm"
SMOOTHING_FWHM = 5.0
SMOOTHING_LABEL = "smoothed5mm"
TEST_SUBJECT = "sub-P15"

# ------------------------------------------------------------
# Runtime flags
# ------------------------------------------------------------

# First run of this new notebook: keep RUN_FIRST_LEVEL=True.
# After all maps are saved successfully, change it to False.
RUN_FIRST_LEVEL = False
OVERWRITE_FIRST_LEVEL = False

RUN_SECOND_LEVEL = True
OVERWRITE_SECOND_LEVEL = True

USE_MEAN_T1W_BACKGROUND = True

paths = ProjectPaths.from_root(PROJECT_ROOT)
dirs = make_analysis_dirs(paths, ANALYSIS_NAME, smoothing_label=SMOOTHING_LABEL)

print("Project root:", paths.project_root)
print("Analysis output:", dirs["out"])
print("dirs keys:", sorted(dirs.keys()))
# Out:
# Project root: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project
# Analysis output: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm
# dirs keys: ['cluster_tables', 'events', 'figures', 'first_level', 'first_level_designs', 'first_level_figures', 'first_level_maps', 'interactive', 'out', 'restart', 'second_level', 'second_level_maps', 'tables', 'thresholded_maps']

# %% [markdown]
# ## Load common inputs from Notebook 00
#
# Notebook 00 defines the final subject list, viewing item labels, filename parsing, checkpoint labels, and the common mean T1w anatomical background.

# %%
# ============================================================
# 2. Load common inputs and mean T1w background
# ============================================================

manifest, subject_table, viewing_item_labels = load_common_inputs(paths)
subjects = get_pre_post_subjects(manifest, no_high_motion=False)
sensitivity_subjects = get_pre_post_subjects(manifest, no_high_motion=True)

sessions = manifest["sessions"]

print("Main sample N:", len(subjects))
print("Sensitivity no-high-motion N:", len(sensitivity_subjects))
print("Sessions:", sessions)

assert "mean_anat" in manifest, (
    "Mean anatomical background missing from manifest. "
    "Rerun Notebook 00 after adding the mean T1w section."
)

mean_t1w_path = Path(manifest["mean_anat"]["mean_t1w_path"])
assert mean_t1w_path.exists(), f"Missing mean T1w file: {mean_t1w_path}"
mean_t1w_img = load_img(str(mean_t1w_path))

print("\nLoaded mean T1w anatomical background:")
print(mean_t1w_path)
print("Mean T1w shape:", mean_t1w_img.shape)

display(subject_table)
display(viewing_item_labels.head())
# Out:
# Main sample N: 27
# Sensitivity no-high-motion N: 25
# Sessions: {'pre': 'ses-01', 'post': 'ses-05', 'task': 'viewing', 'run': '01', 'bold_space': 'MNI152NLin2009cAsym'}
#
# Loaded mean T1w anatomical background:
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/common_inputs/mean_anat/mean_T1w_prepost_N27_subjects_MNI152NLin2009cAsym.nii.gz
# Mean T1w shape: (193, 229, 193)
#     subject  included_primary_post_only  included_pre_post_N27  \
# 0   sub-P10                        True                   True
# 1   sub-P12                        True                   True
# 2   sub-P13                        True                   True
# 3   sub-P14                        True                   True
# 4   sub-P15                        True                   True
# 5   sub-P16                        True                   True
# 6   sub-P17                        True                   True
# 7   sub-P18                        True                   True
# 8   sub-P19                        True                   True
# 9   sub-P21                        True                   True
# 10  sub-P22                        True                   True
# 11  sub-P23                        True                   True
# 12  sub-P25                        True                   True
# 13  sub-P27                        True                   True
# 14  sub-P31                        True                   True
# 15  sub-P34                        True                   True
# 16  sub-P35                        True                   True
# 17  sub-P36                        True                   True
# 18  sub-P37                        True                  False
# 19  sub-P41                        True                   True
# 20  sub-P42                        True                   True
# 21  sub-P43                        True                   True
# 22  sub-P44                        True                   True
# 23  sub-P45                        True                   True
# 24  sub-P47                        True                   True
# 25  sub-P48                        True                   True
# 26  sub-P50                        True                   True
# 27  sub-P51                        True                   True
#
#     included_pre_post_no_high_motion_N25  excluded_from_pre_post  \
# 0                                   True                   False
# 1                                   True                   False
# 2                                   True                   False
# 3                                   True                   False
# 4                                   True                   False
# 5                                   True                   False
# 6                                   True                   False
# 7                                   True                   False
# 8                                  False                   False
# 9                                  False                   False
# 10                                  True                   False
# 11                                  True                   False
# 12                                  True                   False
# 13                                  True                   False
# 14                                  True                   False
# 15                                  True                   False
# 16                                  True                   False
# 17                                  True                   False
# 18                                 False                    True
# 19                                  True                   False
# 20                                  True                   False
# 21                                  True                   False
# 22                                  True                   False
# 23                                  True                   False
# 24                                  True                   False
# 25                                  True                   False
# 26                                  True                   False
# 27                                  True                   False
#
#     high_motion_flag  \
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
#
#                                                                                 exclusion_reason
# 0                                                                                            NaN
# 1                                                                                            NaN
# 2                                                                                            NaN
# 3                                                                                            NaN
# 4                                                                                            NaN
# 5                                                                                            NaN
# 6                                                                                            NaN
# 7                                                                                            NaN
# 8                                                             High-motion sensitivity exclusion.
# 9                                                             High-motion sensitivity exclusion.
# 10                                                                                           NaN
# 11                                                                                           NaN
# 12                                                                                           NaN
# 13                                                                                           NaN
# 14                                                                                           NaN
# 15                                                                                           NaN
# 16                                                                                           NaN
# 17                                                                                           NaN
# 18  Excluded from pre/post analyses: high PRE non-response note and pre/post image-set mismatch.
# 19                                                                                           NaN
# 20                                                                                           NaN
# 21                                                                                           NaN
# 22                                                                                           NaN
# 23                                                                                           NaN
# 24                                                                                           NaN
# 25                                                                                           NaN
# 26                                                                                           NaN
# 27                                                                                           NaN
#    subject session  run   onset  duration                 image_file  \
# 0  sub-P10  ses-01    1   4.634     3.017     maya_3_e3_6_r_h_v1_old
# 1  sub-P10  ses-01    1  11.701     3.017  wealth_5_e3_7_nr_o_v1_old
# 2  sub-P10  ses-01    1  17.934     3.017  pirate_6_e2_13_r_h_v1_old
# 3  sub-P10  ses-01    1  24.534     3.017              viking_11_new
# 4  sub-P10  ses-01    1  30.451     3.016  pirate_7_e3_1_nr_h_v1_old
#
#   source_image_column phase   theme  item_id episode  episode_number  \
# 0               event   pre    maya      3.0      e3             3.0
# 1               event   pre  wealth      5.0      e3             3.0
# 2               event   pre  pirate      6.0      e2             2.0
# 3               event   pre     NaN      NaN     NaN             NaN
# 4               event   pre  pirate      7.0      e3             3.0
#
#    checkpoint_index  checkpoint_index_out_of checkpoint_third  \
# 0               6.0                       16           middle
# 1               7.0                       16           middle
# 2              13.0                       16             late
# 3               NaN                       16              NaN
# 4               1.0                       16            early
#
#   relevance_from_filename object_category_from_filename old_new  \
# 0                relevant                         human     old
# 1              irrelevant                        object     old
# 2                relevant                         human     old
# 3                     NaN                           NaN     new
# 4              irrelevant                         human     old
#
#    stimulus_version  relevance_condition  spatial_accuracy_z  \
# 0               1.0                  NaN                 NaN
# 1               1.0                  NaN                 NaN
# 2               1.0                  NaN                 NaN
# 3               NaN                  NaN                 NaN
# 4               1.0                  NaN                 NaN
#
#    spatial_accuracy_condition_centered   relevance encoding_phase_third
# 0                                  NaN    relevant               middle
# 1                                  NaN  irrelevant               middle
# 2                                  NaN    relevant                 late
# 3                                  NaN         NaN                  NaN
# 4                                  NaN  irrelevant                early

# %% [markdown]
# ## Design
#
# This notebook estimates a **single-run POST-viewing GLM** for each subject.
#
# The task regressors are:
#
# $$
# \beta_{\mathrm{post,oldRel}},\quad
# \beta_{\mathrm{post,oldIrrel}},\quad
# \beta_{\mathrm{post,new}}.
# $$
#
# The model also includes fMRIPrep confounds: motion, white matter, CSF, and high-pass cosine regressors.
#
# Expected event counts per subject:
#
# ```text
# post_oldRel   = 144
# post_oldIrrel = 144
# post_new      = 96
# ```

# %% [markdown]
# ## Contrasts
#
# ### Relevant old > new
#
# $$
# C_{\mathrm{post,oldRel>new}}
# =
# \beta_{\mathrm{post,oldRel}}
# -
# \beta_{\mathrm{post,new}}.
# $$
#
# ### Irrelevant old > new
#
# $$
# C_{\mathrm{post,oldIrrel>new}}
# =
# \beta_{\mathrm{post,oldIrrel}}
# -
# \beta_{\mathrm{post,new}}.
# $$
#
# ### Relevant old > irrelevant old
#
# $$
# C_{\mathrm{post,rel>irrel}}
# =
# \beta_{\mathrm{post,oldRel}}
# -
# \beta_{\mathrm{post,oldIrrel}}.
# $$
#
# This is the main POST-only relevance contrast.

# %%
# ============================================================
# 3. Define contrasts and save contrast table
# ============================================================

contrast_specs = make_post_relevance_old_new_contrasts()
contrast_table = contrast_specs_to_table(contrast_specs)

contrast_table_path = dirs["tables"] / f"{ANALYSIS_NAME}_contrast_definitions.csv"
contrast_table.to_csv(contrast_table_path, index=False)

display(contrast_table)
print("Saved:", contrast_table_path)
# Out:
#                          contrast                            priority  \
# 0              post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1            post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 2               post_rel_gt_irrel            05_post_relevance_effect
# 3               post_irrel_gt_rel   05_post_reverse_relevance_control
# 4  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 5             post_old_gt_new_avg      05_post_all_old_vs_new_average
#
#                                                                                                   formula  \
# 0                                              $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 1                                            $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 2                                         $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
# 3                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 4  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 5  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
#
#                                                             interpretation  \
# 0                              POST relevant old images > POST new images.
# 1                            POST irrelevant old images > POST new images.
# 2                   POST relevant old images > POST irrelevant old images.
# 3  Reverse control: POST irrelevant old images > POST relevant old images.
# 4   POST relevant old images > average of irrelevant old and new controls.
# 5   POST old images, averaging relevant and irrelevant, > POST new images.
#
#    post_oldRel  post_new  post_oldIrrel
# 0          1.0      -1.0            0.0
# 1          0.0      -1.0            1.0
# 2          1.0       0.0           -1.0
# 3         -1.0       0.0            1.0
# 4          1.0      -0.5           -0.5
# 5          0.5      -1.0            0.5
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_contrast_definitions.csv

# %% [markdown]
# ## Event relabelling
#
# We create one clean POST event table per subject with four BIDS-compatible columns:
#
# ```text
# onset, duration, trial_type, modulation
# ```
#
# Trial types are:
#
# ```text
# post_oldRel
# post_oldIrrel
# post_new
# post_other
# ```

# %%
# ============================================================
# 4. Create POST relevance event files and event-count QC
# ============================================================

for subject in subjects:
    save_post_relevance_subject_events(
        viewing_item_labels=viewing_item_labels,
        subject=subject,
        events_dir=dirs["events"],
        phase="post",
    )

event_qc, all_events_long = build_post_relevance_event_qc(
    viewing_item_labels=viewing_item_labels,
    subjects=subjects,
    events_dir=dirs["events"],
    phase="post",
)

event_qc_path = dirs["tables"] / f"{ANALYSIS_NAME}_event_count_qc.csv"
all_events_path = dirs["events"] / f"all_subjects_{ANALYSIS_NAME}_events_long.tsv"

event_qc.to_csv(event_qc_path, index=False)
all_events_long.to_csv(all_events_path, sep="\t", index=False)

print("Saved event QC:", event_qc_path)
print("Saved all events:", all_events_path)

print("\nEvent counts by trial type:")
display(
    all_events_long
    .groupby(["trial_type"])
    .size()
    .reset_index(name="n")
)

display(event_qc.head())

assert (event_qc["n_post_oldRel"] == 144).all(), "Expected 144 relevant old trials per subject."
assert (event_qc["n_post_oldIrrel"] == 144).all(), "Expected 144 irrelevant old trials per subject."
assert (event_qc["n_post_new"] == 96).all(), "Expected 96 new trials per subject."
assert (event_qc["n_post_other"] == 0).all(), "Unexpected post_other events found."

print("Event QC passed.")
# Out:
# Saved event QC: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_event_count_qc.csv
# Saved all events: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/all_subjects_post_relevance_old_new_viewing_glm_events_long.tsv
#
# Event counts by trial type:
#       trial_type     n
# 0       post_new  2592
# 1  post_oldIrrel  3888
# 2    post_oldRel  3888
#    subject phase  n_events  n_post_oldRel  n_post_oldIrrel  n_post_new  \
# 0  sub-P10  post       384            144              144          96
# 1  sub-P12  post       384            144              144          96
# 2  sub-P13  post       384            144              144          96
# 3  sub-P14  post       384            144              144          96
# 4  sub-P15  post       384            144              144          96
#
#    n_post_other  \
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#
#                                                                                                                                                        events_path
# 0  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/sub-P10_post_task-vi...
# 1  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/sub-P12_post_task-vi...
# 2  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/sub-P13_post_task-vi...
# 3  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/sub-P14_post_task-vi...
# 4  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/preprocessed/relabeled_events_post_relevance_old_new_viewing_glm/sub-P15_post_task-vi...
# Event QC passed.

# %% [markdown]
# ## Single-subject design preview
#
# Before running all subjects, we fit one example subject and inspect the design matrix and contrast vectors. This cell does **not** save first-level contrast maps.

# %%
# ============================================================
# 5. Single-subject design and contrast preview
# ============================================================

import matplotlib.pyplot as plt
from nilearn.plotting import plot_design_matrix

preview_result = run_post_relevance_first_level_subject(
    subject=TEST_SUBJECT,
    paths=paths,
    viewing_item_labels=viewing_item_labels,
    contrast_specs=contrast_specs,
    output_dirs=dirs,
    sessions=sessions,
    smoothing_fwhm=SMOOTHING_FWHM,
    smoothing_label=SMOOTHING_LABEL,
    hrf_model="spm",
    save_outputs=False,
    make_design_plot=False,
    return_model=True,
)

preview_subject_qc = preview_result["subject_qc"]
preview_contrast_qc = preview_result["contrast_qc"]
design_matrices = preview_result["design_matrices"]

preview_subject_qc_path = (
    dirs["tables"]
    / f"{ANALYSIS_NAME}_{TEST_SUBJECT}_design_preview_subject_qc.csv"
)

preview_contrast_qc_path = (
    dirs["tables"]
    / f"{ANALYSIS_NAME}_{TEST_SUBJECT}_contrast_vector_preview_qc.csv"
)

preview_subject_qc.to_csv(preview_subject_qc_path, index=False)
preview_contrast_qc.to_csv(preview_contrast_qc_path, index=False)

print("Subject QC preview:")
display(preview_subject_qc)

print("Contrast-vector preview:")
display(preview_contrast_qc)

assert not preview_contrast_qc.groupby("contrast")["is_null_vector"].all().any()

design_matrix_dir = dirs["figures"] / "design_matrices"
design_matrix_dir.mkdir(parents=True, exist_ok=True)

design_matrix_table_dir = dirs["tables"] / "design_matrices"
design_matrix_table_dir.mkdir(parents=True, exist_ok=True)

for run_idx, design_matrix in enumerate(design_matrices, start=1):
    print("=" * 80)
    print(f"{TEST_SUBJECT} — design matrix run {run_idx}")
    print("Shape:", design_matrix.shape)

    task_columns = [
        col for col in design_matrix.columns
        if col.startswith("post_")
    ]

    print("Task regressors:")
    print(task_columns)

    design_matrix_csv_path = (
        design_matrix_table_dir
        / f"{ANALYSIS_NAME}_{TEST_SUBJECT}_run-{run_idx}_design_matrix_{SMOOTHING_LABEL}.csv"
    )

    design_matrix.to_csv(design_matrix_csv_path)

    # Important: this Nilearn version does not support ax=...
    plot_design_matrix(design_matrix)

    fig = plt.gcf()
    fig.set_size_inches(14, 6)

    plt.title(
        f"{TEST_SUBJECT} design matrix, run {run_idx}\n"
        "POST relevance old/new GLM"
    )

    design_matrix_fig_path = (
        design_matrix_dir
        / f"{ANALYSIS_NAME}_{TEST_SUBJECT}_run-{run_idx}_design_matrix_{SMOOTHING_LABEL}.png"
    )

    fig.savefig(design_matrix_fig_path, dpi=300, bbox_inches="tight")
    plt.show()

    print("Saved design matrix CSV:", design_matrix_csv_path)
    print("Saved design matrix figure:", design_matrix_fig_path)

print("Design and contrast-vector preview passed.")
# Out:
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Subject QC preview:
#    subject phase session   tr  n_scans  n_events  \
# 0  sub-P15  post  ses-05  1.3     1995       384
#
#                           event_types  n_confounds  \
# 0  post_new;post_oldIrrel;post_oldRel           65
#
#    sample_mask_originally_none  sample_masks_passed_to_nilearn  \
# 0                         True                           False
#
#    n_design_columns  \
# 0                69
#
#                                                                                                                                                     design_columns
# 0  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# Contrast-vector preview:
#    subject                        contrast  \
# 0  sub-P15              post_oldRel_gt_new
# 1  sub-P15            post_oldIrrel_gt_new
# 2  sub-P15               post_rel_gt_irrel
# 3  sub-P15               post_irrel_gt_rel
# 4  sub-P15  post_oldRel_gt_oldIrrelNew_avg
# 5  sub-P15             post_old_gt_new_avg
#
#                              priority  run  n_design_columns  \
# 0         05_post_relevant_old_vs_new    1                69
# 1       05_post_irrelevant_old_vs_new    1                69
# 2            05_post_relevance_effect    1                69
# 3   05_post_reverse_relevance_control    1                69
# 4  05_post_relevant_vs_other_controls    1                69
# 5      05_post_all_old_vs_new_average    1                69
#
#    n_nonzero_weights                  nonzero_regressors nonzero_weights  \
# 0                  2                post_new;post_oldRel        -1.0;1.0
# 1                  2              post_new;post_oldIrrel        -1.0;1.0
# 2                  2           post_oldIrrel;post_oldRel        -1.0;1.0
# 3                  2           post_oldIrrel;post_oldRel        1.0;-1.0
# 4                  3  post_new;post_oldIrrel;post_oldRel   -0.5;-0.5;1.0
# 5                  3  post_new;post_oldIrrel;post_oldRel    -1.0;0.5;0.5
#
#   missing_regressors_expected  is_null_vector
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# ================================================================================
# sub-P15 — design matrix run 1
# Shape: (1995, 69)
# Task regressors:
# ['post_new', 'post_oldIrrel', 'post_oldRel']
# Saved design matrix CSV: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/design_matrices/post_relevance_old_new_viewing_glm_sub-P15_run-1_design_matrix_smoothed5mm.csv
# Saved design matrix figure: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/design_matrices/post_relevance_old_new_viewing_glm_sub-P15_run-1_design_matrix_smoothed5mm.png
# Design and contrast-vector preview passed.

# %% [markdown]
# ## Restart-safe first-level GLM
#
# The first-level GLM is the slow part. This notebook is configured so that:
#
# - `RUN_FIRST_LEVEL=True` fits first-level models and saves maps immediately;
# - `RUN_FIRST_LEVEL=False` loads/verifies existing maps;
# - `OVERWRITE_FIRST_LEVEL=False` runs only missing or incomplete subjects.
#
# After a successful first run, keep `RUN_FIRST_LEVEL=False`.

# %%
# ============================================================
# 6. Run, recover, or load first-level GLM results
# ============================================================

first_level_qc_path = dirs["tables"] / f"{ANALYSIS_NAME}_first_level_qc_{SMOOTHING_LABEL}.csv"
first_level_contrast_qc_path = dirs["tables"] / f"{ANALYSIS_NAME}_first_level_contrast_qc_{SMOOTHING_LABEL}.csv"
failed_subjects_path = dirs["tables"] / f"{ANALYSIS_NAME}_failed_subjects_{SMOOTHING_LABEL}.csv"
map_qc_path = dirs["tables"] / f"{ANALYSIS_NAME}_first_level_map_qc_{SMOOTHING_LABEL}.csv"


def subject_has_all_first_level_maps(subject, contrast_specs, dirs, smoothing_label):
    for contrast_name in contrast_specs.keys():
        z_path = first_level_map_path(dirs, subject, contrast_name, smoothing_label, map_type="z")
        effect_path = first_level_map_path(dirs, subject, contrast_name, smoothing_label, map_type="effect")
        if not z_path.exists() or not effect_path.exists():
            return False
    return True


def recover_first_level_qc_from_saved_maps(subjects, contrast_specs, dirs, smoothing_label):
    recovered_map_rows = []
    recovered_qc_rows = []
    recovered_contrast_rows = []

    for subject in subjects:
        subject_all_maps_exist = True
        for contrast_name in contrast_specs.keys():
            z_path = first_level_map_path(dirs, subject, contrast_name, smoothing_label, map_type="z")
            effect_path = first_level_map_path(dirs, subject, contrast_name, smoothing_label, map_type="effect")

            z_exists = z_path.exists()
            effect_exists = effect_path.exists()
            if not z_exists or not effect_exists:
                subject_all_maps_exist = False

            recovered_map_rows.append({
                "subject": subject,
                "contrast": contrast_name,
                "z_map_path": str(z_path),
                "effect_map_path": str(effect_path),
                "z_map_exists": z_exists,
                "effect_map_exists": effect_exists,
            })
            recovered_contrast_rows.append({
                "subject": subject,
                "contrast": contrast_name,
                "z_map_path": str(z_path),
                "effect_map_path": str(effect_path),
                "z_map_exists": z_exists,
                "effect_map_exists": effect_exists,
                "recovered_from_saved_maps": True,
            })

        recovered_qc_rows.append({
            "subject": subject,
            "all_expected_first_level_maps_exist": subject_all_maps_exist,
            "recovered_from_saved_maps": True,
        })

    recovered_map_qc = pd.DataFrame(recovered_map_rows)
    first_level_qc = pd.DataFrame(recovered_qc_rows)
    first_level_contrast_qc = pd.DataFrame(recovered_contrast_rows)

    failed_subjects = first_level_qc.loc[
        ~first_level_qc["all_expected_first_level_maps_exist"],
        ["subject"],
    ].copy()

    if len(failed_subjects) > 0:
        failed_subjects["error_type"] = "MissingFirstLevelMaps"
        failed_subjects["error_message"] = "At least one expected first-level z/effect map is missing."
    else:
        failed_subjects = pd.DataFrame(columns=["subject", "error_type", "error_message"])

    return recovered_map_qc, first_level_qc, first_level_contrast_qc, failed_subjects


existing_subjects = [
    subject for subject in subjects
    if subject_has_all_first_level_maps(subject, contrast_specs, dirs, SMOOTHING_LABEL)
]
missing_subjects = [subject for subject in subjects if subject not in existing_subjects]

print("Existing complete first-level subjects:", len(existing_subjects))
print("Missing/incomplete first-level subjects:", len(missing_subjects))
if missing_subjects:
    print("Missing/incomplete:", missing_subjects)

if RUN_FIRST_LEVEL:
    subjects_to_run = subjects if OVERWRITE_FIRST_LEVEL else missing_subjects
    print("\nRUN_FIRST_LEVEL=True")
    print("Subjects to run:", subjects_to_run)

    first_level_qc_rows = []
    first_level_contrast_qc_rows = []
    failed_rows = []

    for subject in subjects_to_run:
        print("=" * 80)
        print("Running POST relevance first-level GLM:", subject)
        try:
            subject_qc, contrast_qc = run_post_relevance_first_level_subject(
                subject=subject,
                paths=paths,
                viewing_item_labels=viewing_item_labels,
                contrast_specs=contrast_specs,
                output_dirs=dirs,
                sessions=sessions,
                smoothing_fwhm=SMOOTHING_FWHM,
                smoothing_label=SMOOTHING_LABEL,
                hrf_model="spm",
                save_outputs=True,
                make_design_plot=False,
            )
            first_level_qc_rows.append(subject_qc)
            first_level_contrast_qc_rows.append(contrast_qc)
            print("Finished:", subject)
        except Exception as exc:
            failed_rows.append({
                "subject": subject,
                "error_type": type(exc).__name__,
                "error_message": str(exc),
            })
            print("FAILED:", subject, type(exc).__name__, str(exc))

    new_first_level_qc = pd.concat(first_level_qc_rows, ignore_index=True) if first_level_qc_rows else pd.DataFrame()
    new_first_level_contrast_qc = pd.concat(first_level_contrast_qc_rows, ignore_index=True) if first_level_contrast_qc_rows else pd.DataFrame()
    failed_subjects_new = pd.DataFrame(failed_rows)

    if first_level_qc_path.exists() and not OVERWRITE_FIRST_LEVEL:
        old_first_level_qc = pd.read_csv(first_level_qc_path)
        first_level_qc = pd.concat([old_first_level_qc, new_first_level_qc], ignore_index=True)
        if "subject" in first_level_qc.columns:
            first_level_qc = first_level_qc.drop_duplicates(subset=["subject"], keep="last")
    else:
        first_level_qc = new_first_level_qc

    if first_level_contrast_qc_path.exists() and not OVERWRITE_FIRST_LEVEL:
        old_first_level_contrast_qc = pd.read_csv(first_level_contrast_qc_path)
        first_level_contrast_qc = pd.concat([old_first_level_contrast_qc, new_first_level_contrast_qc], ignore_index=True)
        dedup_cols = [col for col in ["subject", "contrast", "run"] if col in first_level_contrast_qc.columns]
        if dedup_cols:
            first_level_contrast_qc = first_level_contrast_qc.drop_duplicates(subset=dedup_cols, keep="last")
    else:
        first_level_contrast_qc = new_first_level_contrast_qc

    failed_subjects = failed_subjects_new

else:
    print("\nRUN_FIRST_LEVEL=False, recovering/loading existing first-level outputs.")
    if first_level_qc_path.exists() and first_level_contrast_qc_path.exists():
        first_level_qc = pd.read_csv(first_level_qc_path)
        first_level_contrast_qc = pd.read_csv(first_level_contrast_qc_path)
        failed_subjects = pd.read_csv(failed_subjects_path) if failed_subjects_path.exists() else pd.DataFrame(columns=["subject", "error_type", "error_message"])
    else:
        print("QC tables missing. Recovering QC from saved maps.")
        recovered_map_qc, first_level_qc, first_level_contrast_qc, failed_subjects = recover_first_level_qc_from_saved_maps(
            subjects, contrast_specs, dirs, SMOOTHING_LABEL
        )
        recovered_map_qc.to_csv(map_qc_path, index=False)

# Always recover final map QC from files, because this is the real restart-safe check.
recovered_map_qc, recovered_qc, recovered_contrast_qc, recovered_failed = recover_first_level_qc_from_saved_maps(
    subjects, contrast_specs, dirs, SMOOTHING_LABEL
)
map_qc = verify_first_level_maps(subjects, contrast_specs, dirs, SMOOTHING_LABEL)

if len(failed_subjects) == 0 and len(recovered_failed) > 0:
    failed_subjects = recovered_failed

first_level_qc.to_csv(first_level_qc_path, index=False)
first_level_contrast_qc.to_csv(first_level_contrast_qc_path, index=False)
failed_subjects.to_csv(failed_subjects_path, index=False)
map_qc.to_csv(map_qc_path, index=False)

display(map_qc)
display(first_level_qc)
display(failed_subjects)

assert (map_qc["n_z_maps"] == len(subjects)).all(), (
    "Some first-level z-maps are missing. Set RUN_FIRST_LEVEL=True and OVERWRITE_FIRST_LEVEL=False."
)
assert (map_qc["n_effect_maps"] == len(subjects)).all(), (
    "Some first-level effect maps are missing. Set RUN_FIRST_LEVEL=True and OVERWRITE_FIRST_LEVEL=False."
)
assert len(failed_subjects) == 0, "Some subjects failed or have missing maps. Inspect failed_subjects."

print("\nFirst-level ready.")
print("Saved:", first_level_qc_path)
print("Saved:", first_level_contrast_qc_path)
print("Saved:", failed_subjects_path)
# Out:
# Existing complete first-level subjects: 0
# Missing/incomplete first-level subjects: 27
# Missing/incomplete: ['sub-P10', 'sub-P12', 'sub-P13', 'sub-P14', 'sub-P15', 'sub-P16', 'sub-P17', 'sub-P18', 'sub-P19', 'sub-P21', 'sub-P22', 'sub-P23', 'sub-P25', 'sub-P27', 'sub-P31', 'sub-P34', 'sub-P35', 'sub-P36', 'sub-P41', 'sub-P42', 'sub-P43', 'sub-P44', 'sub-P45', 'sub-P47', 'sub-P48', 'sub-P50', 'sub-P51']
#
# RUN_FIRST_LEVEL=True
# Subjects to run: ['sub-P10', 'sub-P12', 'sub-P13', 'sub-P14', 'sub-P15', 'sub-P16', 'sub-P17', 'sub-P18', 'sub-P19', 'sub-P21', 'sub-P22', 'sub-P23', 'sub-P25', 'sub-P27', 'sub-P31', 'sub-P34', 'sub-P35', 'sub-P36', 'sub-P41', 'sub-P42', 'sub-P43', 'sub-P44', 'sub-P45', 'sub-P47', 'sub-P48', 'sub-P50', 'sub-P51']
# ================================================================================
# Running POST relevance first-level GLM: sub-P10
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P10
# ================================================================================
# Running POST relevance first-level GLM: sub-P12
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P12
# ================================================================================
# Running POST relevance first-level GLM: sub-P13
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P13
# ================================================================================
# Running POST relevance first-level GLM: sub-P14
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P14
# ================================================================================
# Running POST relevance first-level GLM: sub-P15
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P15
# ================================================================================
# Running POST relevance first-level GLM: sub-P16
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P16
# ================================================================================
# Running POST relevance first-level GLM: sub-P17
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P17
# ================================================================================
# Running POST relevance first-level GLM: sub-P18
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P18
# ================================================================================
# Running POST relevance first-level GLM: sub-P19
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P19
# ================================================================================
# Running POST relevance first-level GLM: sub-P21
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P21
# ================================================================================
# Running POST relevance first-level GLM: sub-P22
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P22
# ================================================================================
# Running POST relevance first-level GLM: sub-P23
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P23
# ================================================================================
# Running POST relevance first-level GLM: sub-P25
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P25
# ================================================================================
# Running POST relevance first-level GLM: sub-P27
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P27
# ================================================================================
# Running POST relevance first-level GLM: sub-P31
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P31
# ================================================================================
# Running POST relevance first-level GLM: sub-P34
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P34
# ================================================================================
# Running POST relevance first-level GLM: sub-P35
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P35
# ================================================================================
# Running POST relevance first-level GLM: sub-P36
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P36
# ================================================================================
# Running POST relevance first-level GLM: sub-P41
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P41
# ================================================================================
# Running POST relevance first-level GLM: sub-P42
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P42
# ================================================================================
# Running POST relevance first-level GLM: sub-P43
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P43
# ================================================================================
# Running POST relevance first-level GLM: sub-P44
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P44
# ================================================================================
# Running POST relevance first-level GLM: sub-P45
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P45
# ================================================================================
# Running POST relevance first-level GLM: sub-P47
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P47
# ================================================================================
# Running POST relevance first-level GLM: sub-P48
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P48
# ================================================================================
# Running POST relevance first-level GLM: sub-P50
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P50
# ================================================================================
# Running POST relevance first-level GLM: sub-P51
# [FirstLevelModel.fit] A 'modulation' column was found in the given events data and is used.
# Finished: sub-P51
#                          contrast                            priority  \
# 0              post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1            post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 2               post_rel_gt_irrel            05_post_relevance_effect
# 3               post_irrel_gt_rel   05_post_reverse_relevance_control
# 4  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 5             post_old_gt_new_avg      05_post_all_old_vs_new_average
#
#    n_subjects  n_z_maps  n_effect_maps
# 0          27        27             27
# 1          27        27             27
# 2          27        27             27
# 3          27        27             27
# 4          27        27             27
# 5          27        27             27
#     subject phase session   tr  n_scans  n_events  \
# 0   sub-P10  post  ses-05  1.3     1994       384
# 1   sub-P12  post  ses-05  1.3     1954       384
# 2   sub-P13  post  ses-05  1.3     1957       384
# 3   sub-P14  post  ses-05  1.3     1922       384
# 4   sub-P15  post  ses-05  1.3     1995       384
# 5   sub-P16  post  ses-05  1.3     1955       384
# 6   sub-P17  post  ses-05  1.3     1946       384
# 7   sub-P18  post  ses-05  1.3     1993       384
# 8   sub-P19  post  ses-05  1.3     1945       384
# 9   sub-P21  post  ses-05  1.3     1961       384
# 10  sub-P22  post  ses-05  1.3     2014       384
# 11  sub-P23  post  ses-05  1.3     1879       384
# 12  sub-P25  post  ses-05  1.3     1911       384
# 13  sub-P27  post  ses-05  1.3     1946       384
# 14  sub-P31  post  ses-05  1.3     1733       384
# 15  sub-P34  post  ses-05  1.3     1649       384
# 16  sub-P35  post  ses-05  1.3     1886       384
# 17  sub-P36  post  ses-05  1.3     1723       384
# 18  sub-P41  post  ses-05  1.3     1666       384
# 19  sub-P42  post  ses-05  1.3     1713       384
# 20  sub-P43  post  ses-05  1.3     1618       384
# 21  sub-P44  post  ses-05  1.3     1668       384
# 22  sub-P45  post  ses-05  1.3     1658       384
# 23  sub-P47  post  ses-05  1.3     1610       384
# 24  sub-P48  post  ses-05  1.3     1702       384
# 25  sub-P50  post  ses-05  1.3     1739       384
# 26  sub-P51  post  ses-05  1.3     1703       384
#
#                            event_types  n_confounds  \
# 0   post_new;post_oldIrrel;post_oldRel           65
# 1   post_new;post_oldIrrel;post_oldRel           64
# 2   post_new;post_oldIrrel;post_oldRel           64
# 3   post_new;post_oldIrrel;post_oldRel           64
# 4   post_new;post_oldIrrel;post_oldRel           65
# 5   post_new;post_oldIrrel;post_oldRel           64
# 6   post_new;post_oldIrrel;post_oldRel           64
# 7   post_new;post_oldIrrel;post_oldRel           65
# 8   post_new;post_oldIrrel;post_oldRel           64
# 9   post_new;post_oldIrrel;post_oldRel           64
# 10  post_new;post_oldIrrel;post_oldRel           65
# 11  post_new;post_oldIrrel;post_oldRel           63
# 12  post_new;post_oldIrrel;post_oldRel           63
# 13  post_new;post_oldIrrel;post_oldRel           64
# 14  post_new;post_oldIrrel;post_oldRel           60
# 15  post_new;post_oldIrrel;post_oldRel           58
# 16  post_new;post_oldIrrel;post_oldRel           63
# 17  post_new;post_oldIrrel;post_oldRel           59
# 18  post_new;post_oldIrrel;post_oldRel           58
# 19  post_new;post_oldIrrel;post_oldRel           59
# 20  post_new;post_oldIrrel;post_oldRel           57
# 21  post_new;post_oldIrrel;post_oldRel           58
# 22  post_new;post_oldIrrel;post_oldRel           58
# 23  post_new;post_oldIrrel;post_oldRel           57
# 24  post_new;post_oldIrrel;post_oldRel           59
# 25  post_new;post_oldIrrel;post_oldRel           60
# 26  post_new;post_oldIrrel;post_oldRel           59
#
#     sample_mask_originally_none  sample_masks_passed_to_nilearn  \
# 0                          True                           False
# 1                          True                           False
# 2                          True                           False
# 3                          True                           False
# 4                          True                           False
# 5                          True                           False
# 6                          True                           False
# 7                          True                           False
# 8                          True                           False
# 9                          True                           False
# 10                         True                           False
# 11                         True                           False
# 12                         True                           False
# 13                         True                           False
# 14                         True                           False
# 15                         True                           False
# 16                         True                           False
# 17                         True                           False
# 18                         True                           False
# 19                         True                           False
# 20                        False                            True
# 21                        False                            True
# 22                         True                           False
# 23                         True                           False
# 24                         True                           False
# 25                         True                           False
# 26                         True                           False
#
#     n_design_columns  \
# 0                 69
# 1                 68
# 2                 68
# 3                 68
# 4                 69
# 5                 68
# 6                 68
# 7                 69
# 8                 68
# 9                 68
# 10                69
# 11                67
# 12                67
# 13                68
# 14                64
# 15                62
# 16                67
# 17                63
# 18                62
# 19                63
# 20                61
# 21                62
# 22                62
# 23                61
# 24                63
# 25                64
# 26                63
#
#                                                                                                                                                      design_columns
# 0   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 1   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 2   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 3   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 4   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 5   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 6   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 7   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 8   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 9   post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 10  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 11  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 12  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 13  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 14  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 15  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 16  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 17  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 18  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 19  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 20  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 21  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 22  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 23  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 24  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 25  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# 26  post_new;post_oldIrrel;post_oldRel;cosine00;cosine01;cosine02;cosine03;cosine04;cosine05;cosine06;cosine07;cosine08;cosine09;cosine10;cosine11;cosine12;cosi...
# Empty DataFrame
# Columns: []
# Index: []
# First-level ready.
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_first_level_qc_smoothed5mm.csv
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_first_level_contrast_qc_smoothed5mm.csv
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_failed_subjects_smoothed5mm.csv

# %% [markdown]
# ## Verify first-level maps
#
# Each contrast should have one z-map and one effect-size map per subject.

# %%
# ============================================================
# 7. Verify first-level maps
# ============================================================

map_qc = verify_first_level_maps(subjects, contrast_specs, dirs, SMOOTHING_LABEL)
map_qc_path = dirs["tables"] / f"{ANALYSIS_NAME}_first_level_map_qc_{SMOOTHING_LABEL}.csv"
map_qc.to_csv(map_qc_path, index=False)

display(map_qc)
print("Saved:", map_qc_path)

assert (map_qc["n_z_maps"] == len(subjects)).all()
assert (map_qc["n_effect_maps"] == len(subjects)).all()
# Out:
#                          contrast                            priority  \
# 0              post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1            post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 2               post_rel_gt_irrel            05_post_relevance_effect
# 3               post_irrel_gt_rel   05_post_reverse_relevance_control
# 4  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 5             post_old_gt_new_avg      05_post_all_old_vs_new_average
#
#    n_subjects  n_z_maps  n_effect_maps
# 0          27        27             27
# 1          27        27             27
# 2          27        27             27
# 3          27        27             27
# 4          27        27             27
# 5          27        27             27
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_first_level_map_qc_smoothed5mm.csv

# %% [markdown]
# ## Second-level GLM
#
# At the group level, each first-level effect map enters a one-sample test against zero.

# %%
# ============================================================
# 8. Run or load second-level GLM
# ============================================================

second_level_table_path = dirs["tables"] / f"{ANALYSIS_NAME}_second_level_maps_{SMOOTHING_LABEL}.csv"

if RUN_SECOND_LEVEL:
    if second_level_table_path.exists() and not OVERWRITE_SECOND_LEVEL:
        print("RUN_SECOND_LEVEL=True but existing second-level table found.")
        print("OVERWRITE_SECOND_LEVEL=False, loading existing second-level maps.")
        second_level_table = pd.read_csv(second_level_table_path)
    else:
        print("Running second-level GLM.")
        second_level_table = run_second_level_all_contrasts(
            subjects=subjects,
            contrast_specs=contrast_specs,
            output_dirs=dirs,
            smoothing_label=SMOOTHING_LABEL,
        )
        second_level_table.to_csv(second_level_table_path, index=False)
else:
    print("RUN_SECOND_LEVEL=False, loading existing second-level table.")
    assert second_level_table_path.exists(), (
        f"Missing second-level table: {second_level_table_path}. "
        "Set RUN_SECOND_LEVEL=True once to generate it."
    )
    second_level_table = pd.read_csv(second_level_table_path)

display(second_level_table)
print("Second-level table:", second_level_table_path)

assert second_level_table["z_map_exists"].all()
assert second_level_table["effect_map_exists"].all()
# Out:
# Running second-level GLM.
#                          contrast                            priority  \
# 0              post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1            post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 2               post_rel_gt_irrel            05_post_relevance_effect
# 3               post_irrel_gt_rel   05_post_reverse_relevance_control
# 4  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 5             post_old_gt_new_avg      05_post_all_old_vs_new_average
#
#                                                                                                   formula  \
# 0                                              $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 1                                            $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 2                                         $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
# 3                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 4  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 5  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
#
#    n_subjects  \
# 0          27
# 1          27
# 2          27
# 3          27
# 4          27
# 5          27
#
#                                                                                                                                                         z_map_path  \
# 0  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 1  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 2  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 3  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 4  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 5  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
#
#                                                                                                                                                    effect_map_path  \
# 0  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 1  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 2  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 3  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 4  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
# 5  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/maps/g...
#
#    z_map_exists  effect_map_exists
# 0          True               True
# 1          True               True
# 2          True               True
# 3          True               True
# 4          True               True
# 5          True               True
# Second-level table: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_second_level_maps_smoothed5mm.csv

# %% [markdown]
# ## Thresholding and cluster tables
#
# We save corrected threshold summaries and exploratory cluster tables. Visualizations use exploratory thresholds unless corrected maps survive FDR/Bonferroni.

# %%
# ============================================================
# 9. Threshold maps and create cluster tables
# ============================================================

threshold_summary = threshold_group_maps(second_level_table, dirs)
threshold_summary_path = dirs["tables"] / f"{ANALYSIS_NAME}_threshold_summary_{SMOOTHING_LABEL}.csv"
threshold_summary.to_csv(threshold_summary_path, index=False)

cluster_summary, cluster_details = make_cluster_tables(
    second_level_table=second_level_table,
    output_dirs=dirs,
    thresholds=(2.33, 3.0),
    cluster_threshold_voxels=10,
)

cluster_summary_path = dirs["tables"] / f"{ANALYSIS_NAME}_cluster_summary_{SMOOTHING_LABEL}.csv"
cluster_details_path = dirs["tables"] / f"{ANALYSIS_NAME}_cluster_details_{SMOOTHING_LABEL}.csv"
cluster_summary.to_csv(cluster_summary_path, index=False)
cluster_details.to_csv(cluster_details_path, index=False)

print("Threshold summary:")
display(threshold_summary.sort_values(["contrast", "threshold_label"]))

print("Cluster summary:")
display(cluster_summary.sort_values(["contrast", "threshold_label"]))

print("Saved:")
print(threshold_summary_path)
print(cluster_summary_path)
print(cluster_details_path)
# Out:
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.0632781982421875. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.0632781982421875. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.0632781982421875. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.998868703842163. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.998868703842163. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.998868703842163. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.3010334968566895. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.3010334968566895. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.3010334968566895. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.68533992767334. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.68533992767334. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.68533992767334. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.8999218940734863. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.8999218940734863. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 3.8999218940734863. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: FutureWarning:
# From nilearn version>=0.15, the default 'threshold' will be set to 3.090232306167813.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.413140296936035. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.413140296936035. But, you have given threshold=inf.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:85: UserWarning: The given float value must not exceed 4.413140296936035. But, you have given threshold=4.944046259789629.
#   thresholded_img, z_threshold = threshold_stats_img(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:133: UserWarning: No clusters found with stat higher than 3.0
#   table = get_clusters_table(
# Threshold summary:
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:133: UserWarning: No clusters found with stat higher than 3.0
#   table = get_clusters_table(
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/src/island_glm/second_level.py:231: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(all_tables, ignore_index=True)
#                           contrast                            priority  \
# 15               post_irrel_gt_rel   05_post_reverse_relevance_control
# 13               post_irrel_gt_rel   05_post_reverse_relevance_control
# 14               post_irrel_gt_rel   05_post_reverse_relevance_control
# 12               post_irrel_gt_rel   05_post_reverse_relevance_control
# 7             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 5             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 6             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 4             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 3               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 2               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 0               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 19  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 17  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 18  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 16  post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 23             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 21             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 22             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 20             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 11               post_rel_gt_irrel            05_post_relevance_effect
# 9                post_rel_gt_irrel            05_post_relevance_effect
# 10               post_rel_gt_irrel            05_post_relevance_effect
# 8                post_rel_gt_irrel            05_post_relevance_effect
#
#                                                                                                    formula  \
# 15                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 13                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 14                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 12                                         $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,oldRel}}$$
# 7                                             $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 5                                             $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 6                                             $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 4                                             $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 3                                               $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 1                                               $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 2                                               $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 0                                               $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 19  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 17  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 18  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 16  $$\beta_{\mathrm{post,oldRel}}-\frac{1}{2}(\beta_{\mathrm{post,oldIrrel}}+\beta_{\mathrm{post,new}})$$
# 23  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
# 21  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
# 22  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
# 20  $$\frac{1}{2}(\beta_{\mathrm{post,oldRel}}+\beta_{\mathrm{post,oldIrrel}})-\beta_{\mathrm{post,new}}$$
# 11                                         $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
# 9                                          $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
# 10                                         $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
# 8                                          $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,oldIrrel}}$$
#
#                threshold_label height_control  alpha  two_sided  z_threshold  \
# 15    bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 13           fdr_q05_one_sided            fdr  0.050      False          inf
# 14           fdr_q10_one_sided            fdr  0.100      False          inf
# 12  uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
# 7     bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 5            fdr_q05_one_sided            fdr  0.050      False          inf
# 6            fdr_q10_one_sided            fdr  0.100      False          inf
# 4   uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
# 3     bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 1            fdr_q05_one_sided            fdr  0.050      False          inf
# 2            fdr_q10_one_sided            fdr  0.100      False          inf
# 0   uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
# 19    bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 17           fdr_q05_one_sided            fdr  0.050      False          inf
# 18           fdr_q10_one_sided            fdr  0.100      False          inf
# 16  uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
# 23    bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 21           fdr_q05_one_sided            fdr  0.050      False          inf
# 22           fdr_q10_one_sided            fdr  0.100      False          inf
# 20  uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
# 11    bonferroni_p05_one_sided     bonferroni  0.050      False     4.944046
# 9            fdr_q05_one_sided            fdr  0.050      False          inf
# 10           fdr_q10_one_sided            fdr  0.100      False          inf
# 8   uncorrected_p001_one_sided    uncorrected  0.001      False     3.000000
#
#     n_nonzero_voxels     max_z  \
# 15                 0       NaN
# 13                 0       NaN
# 14                 0       NaN
# 12                29  3.685340
# 7                  0       NaN
# 5                  0       NaN
# 6                  0       NaN
# 4                 94  3.998869
# 3                  0       NaN
# 1                  0       NaN
# 2                  0       NaN
# 0                102  4.063278
# 19                 0       NaN
# 17                 0       NaN
# 18                 0       NaN
# 16               117  3.899922
# 23                 0       NaN
# 21                 0       NaN
# 22                 0       NaN
# 20                92  4.413140
# 11                 0       NaN
# 9                  0       NaN
# 10                 0       NaN
# 8                229  4.301033
#
#                                                                                                                                                thresholded_map_path
# 15  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 13  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 14  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 12  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 7   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 5   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 6   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 4   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 3   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 1   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 2   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 0   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 19  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 17  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 18  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 16  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 23  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 21  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 22  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 20  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 11  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 9   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 10  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# 8   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/thresh...
# Cluster summary:
#                           contrast                            priority  \
# 6                post_irrel_gt_rel   05_post_reverse_relevance_control
# 7                post_irrel_gt_rel   05_post_reverse_relevance_control
# 2             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 3             post_oldIrrel_gt_new       05_post_irrelevant_old_vs_new
# 0               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 1               post_oldRel_gt_new         05_post_relevant_old_vs_new
# 8   post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 9   post_oldRel_gt_oldIrrelNew_avg  05_post_relevant_vs_other_controls
# 10             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 11             post_old_gt_new_avg      05_post_all_old_vs_new_average
# 4                post_rel_gt_irrel            05_post_relevance_effect
# 5                post_rel_gt_irrel            05_post_relevance_effect
#
#    threshold_label  stat_threshold  cluster_threshold_voxels  n_clusters  \
# 6        z_gt_2.33            2.33                        10           4
# 7        z_gt_3.00            3.00                        10           0
# 2        z_gt_2.33            2.33                        10          11
# 3        z_gt_3.00            3.00                        10           2
# 0        z_gt_2.33            2.33                        10          25
# 1        z_gt_3.00            3.00                        10           1
# 8        z_gt_2.33            2.33                        10          27
# 9        z_gt_3.00            3.00                        10           2
# 10       z_gt_2.33            2.33                        10          22
# 11       z_gt_3.00            3.00                        10           0
# 4        z_gt_2.33            2.33                        10          41
# 5        z_gt_3.00            3.00                        10           4
#
#     max_peak_stat  largest_cluster_mm3  \
# 6        3.408719                390.0
# 7             NaN                  NaN
# 2        3.998869               1406.0
# 3        3.747695                203.0
# 0        4.063278                875.0
# 1        3.644219                234.0
# 8        3.899922               1281.0
# 9        3.899922                171.0
# 10       4.413140                890.0
# 11            NaN                  NaN
# 4        4.301033               4843.0
# 5        4.301033                343.0
#
#                                                                                                                                                  cluster_table_path
# 6   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 7   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 2   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 3   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 0   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 1   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 8   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 9   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 10  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 11  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 4   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# 5   /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/second_level_from_smoothed5mm/cluste...
# Saved:
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_threshold_summary_smoothed5mm.csv
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_cluster_summary_smoothed5mm.csv
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_cluster_details_smoothed5mm.csv

# %% [markdown]
# ## Atlas labels for exploratory peaks
#
# The cluster table is labelled with Harvard-Oxford. These labels are useful for reporting, but exact anatomy should still be checked visually.

# %%
# ============================================================
# 10. Label cluster table with Harvard-Oxford atlas
# ============================================================

cluster_details_labeled = label_cluster_table(cluster_details)
cluster_details_labeled_path = dirs["tables"] / f"{ANALYSIS_NAME}_cluster_details_labeled_{SMOOTHING_LABEL}.csv"
cluster_details_labeled.to_csv(cluster_details_labeled_path, index=False)

display(cluster_details_labeled.head(50))
print("Saved:", cluster_details_labeled_path)
# Out:
# [fetch_atlas_harvard_oxford] Dataset found in /home/kroczak/nilearn_data/fsl
# [fetch_atlas_harvard_oxford] Dataset found in /home/kroczak/nilearn_data/fsl
#    Cluster ID     X     Y     Z  Peak Stat  Cluster Size (mm3)  \
# 0           1   4.0 -17.0 -18.0   4.063278               562.0
# 1          1a   6.5  -4.5 -18.0   3.197928                 NaN
# 2           2 -21.0 -24.5  -3.0   3.969147               218.0
# 3           3 -16.0 -29.5 -10.5   3.892725               328.0
# 4          3a -11.0 -29.5 -18.0   2.987828                 NaN
# 5           4 -23.5   0.5  62.0   3.860475               343.0
# 6           5 -28.5  50.5 -15.5   3.682255               171.0
# 7           6 -56.0 -44.5  44.5   3.644219               671.0
# 8           7 -16.0 -12.0 -13.0   3.612307               296.0
# 9           8 -38.5  -9.5 -10.5   3.408904               296.0
# 10         8a -43.5 -17.0  -8.0   2.904542                 NaN
# 11         8b -46.0  -4.5 -10.5   2.801052                 NaN
# 12          9   1.5 -79.5   7.0   3.387083               156.0
# 13         10  -8.5 -99.5  12.0   3.328726               875.0
# 14        10a  -1.0 -97.0   7.0   3.038720                 NaN
# 15        10b  -3.5 -97.0  17.0   2.988703                 NaN
# 16         11  26.5 -22.0  -5.5   3.325845               156.0
# 17         12 -28.5  15.5   7.0   3.307007               312.0
# 18         13  19.0 -39.5 -10.5   3.304642               218.0
# 19         14   1.5 -82.0  -8.0   3.265053               625.0
# 20        14a   6.5 -92.0 -13.0   2.616980                 NaN
# 21         15  24.0   8.0  44.5   3.244661               359.0
# 22        15a  24.0  18.0  47.0   3.223181                 NaN
# 23         16 -18.5 -74.5  44.5   3.199723               296.0
# 24        16a -21.0 -77.0  52.0   2.774927                 NaN
# 25         17  51.5 -57.0  12.0   3.157016               203.0
# 26        17a  54.0 -54.5  19.5   2.765802                 NaN
# 27         18 -16.0 -52.0  -0.5   3.066315               203.0
# 28        18a -11.0 -47.0  -5.5   2.942069                 NaN
# 29         19  -1.0  10.5  49.5   3.045810               187.0
# 30         20 -36.0 -49.5  44.5   3.012621               171.0
# 31         21  -3.5 -67.0  62.0   3.006101               781.0
# 32        21a   1.5 -77.0  52.0   2.948119                 NaN
# 33        21b  -6.0 -59.5  67.0   2.925291                 NaN
# 34         22 -41.0  33.0  39.5   2.951620               218.0
# 35         23 -16.0 -19.5 -20.5   2.948408               203.0
# 36         24  21.5  13.0  62.0   2.747240               171.0
# 37         25  11.5 -34.5 -38.0   2.605267               156.0
# 38          1 -56.0 -44.5  44.5   3.644219               234.0
# 39          1   6.5 -42.0 -35.5   3.998869               453.0
# 40         1a  14.0 -47.0 -35.5   2.970182                 NaN
# 41          2 -28.5 -47.0 -40.5   3.991844               468.0
# 42          3   1.5 -42.0 -53.0   3.892481               156.0
# 43          4   9.0 -34.5 -38.0   3.747695              1406.0
# 44         4a  19.0 -32.0 -38.0   3.743985                 NaN
# 45         4b  16.5 -42.0 -50.5   3.586538                 NaN
# 46          5 -21.0   0.5  62.0   3.744350               250.0
# 47          6  24.0 -42.0 -35.5   3.646660               265.0
# 48          7  29.0  35.5  29.5   3.617227               187.0
# 49          8 -13.5 -32.0 -10.5   3.532409               406.0
#
#                 contrast                       priority  \
# 0     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 1     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 2     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 3     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 4     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 5     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 6     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 7     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 8     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 9     post_oldRel_gt_new    05_post_relevant_old_vs_new
# 10    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 11    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 12    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 13    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 14    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 15    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 16    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 17    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 18    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 19    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 20    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 21    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 22    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 23    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 24    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 25    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 26    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 27    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 28    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 29    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 30    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 31    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 32    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 33    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 34    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 35    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 36    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 37    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 38    post_oldRel_gt_new    05_post_relevant_old_vs_new
# 39  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 40  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 41  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 42  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 43  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 44  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 45  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 46  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 47  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 48  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
# 49  post_oldIrrel_gt_new  05_post_irrelevant_old_vs_new
#
#                                                          formula  \
# 0     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 1     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 2     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 3     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 4     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 5     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 6     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 7     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 8     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 9     $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 10    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 11    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 12    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 13    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 14    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 15    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 16    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 17    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 18    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 19    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 20    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 21    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 22    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 23    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 24    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 25    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 26    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 27    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 28    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 29    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 30    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 31    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 32    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 33    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 34    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 35    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 36    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 37    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 38    $$\beta_{\mathrm{post,oldRel}}-\beta_{\mathrm{post,new}}$$
# 39  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 40  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 41  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 42  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 43  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 44  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 45  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 46  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 47  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 48  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
# 49  $$\beta_{\mathrm{post,oldIrrel}}-\beta_{\mathrm{post,new}}$$
#
#    threshold_label  stat_threshold  cluster_threshold_voxels  \
# 0        z_gt_2.33            2.33                        10
# 1        z_gt_2.33            2.33                        10
# 2        z_gt_2.33            2.33                        10
# 3        z_gt_2.33            2.33                        10
# 4        z_gt_2.33            2.33                        10
# 5        z_gt_2.33            2.33                        10
# 6        z_gt_2.33            2.33                        10
# 7        z_gt_2.33            2.33                        10
# 8        z_gt_2.33            2.33                        10
# 9        z_gt_2.33            2.33                        10
# 10       z_gt_2.33            2.33                        10
# 11       z_gt_2.33            2.33                        10
# 12       z_gt_2.33            2.33                        10
# 13       z_gt_2.33            2.33                        10
# 14       z_gt_2.33            2.33                        10
# 15       z_gt_2.33            2.33                        10
# 16       z_gt_2.33            2.33                        10
# 17       z_gt_2.33            2.33                        10
# 18       z_gt_2.33            2.33                        10
# 19       z_gt_2.33            2.33                        10
# 20       z_gt_2.33            2.33                        10
# 21       z_gt_2.33            2.33                        10
# 22       z_gt_2.33            2.33                        10
# 23       z_gt_2.33            2.33                        10
# 24       z_gt_2.33            2.33                        10
# 25       z_gt_2.33            2.33                        10
# 26       z_gt_2.33            2.33                        10
# 27       z_gt_2.33            2.33                        10
# 28       z_gt_2.33            2.33                        10
# 29       z_gt_2.33            2.33                        10
# 30       z_gt_2.33            2.33                        10
# 31       z_gt_2.33            2.33                        10
# 32       z_gt_2.33            2.33                        10
# 33       z_gt_2.33            2.33                        10
# 34       z_gt_2.33            2.33                        10
# 35       z_gt_2.33            2.33                        10
# 36       z_gt_2.33            2.33                        10
# 37       z_gt_2.33            2.33                        10
# 38       z_gt_3.00            3.00                        10
# 39       z_gt_2.33            2.33                        10
# 40       z_gt_2.33            2.33                        10
# 41       z_gt_2.33            2.33                        10
# 42       z_gt_2.33            2.33                        10
# 43       z_gt_2.33            2.33                        10
# 44       z_gt_2.33            2.33                        10
# 45       z_gt_2.33            2.33                        10
# 46       z_gt_2.33            2.33                        10
# 47       z_gt_2.33            2.33                        10
# 48       z_gt_2.33            2.33                        10
# 49       z_gt_2.33            2.33                        10
#
#                    harvard_oxford_cortical_label  \
# 0                                     Background
# 1                                     Background
# 2                                     Background
# 3      Parahippocampal Gyrus, posterior division
# 4                                     Background
# 5                         Superior Frontal Gyrus
# 6                                   Frontal Pole
# 7        Supramarginal Gyrus, posterior division
# 8                                     Background
# 9                                 Insular Cortex
# 10                                    Background
# 11                                 Planum Polare
# 12                         Supracalcarine Cortex
# 13                                Occipital Pole
# 14                                Occipital Pole
# 15                                Occipital Pole
# 16                                    Background
# 17                                    Background
# 18                                 Lingual Gyrus
# 19                                 Lingual Gyrus
# 20                                    Background
# 21                                    Background
# 22                        Superior Frontal Gyrus
# 23   Lateral Occipital Cortex, superior division
# 24   Lateral Occipital Cortex, superior division
# 25  Middle Temporal Gyrus, temporooccipital part
# 26                                 Angular Gyrus
# 27                                 Lingual Gyrus
# 28                                 Lingual Gyrus
# 29                           Paracingulate Gyrus
# 30       Supramarginal Gyrus, posterior division
# 31                             Precuneous Cortex
# 32                                    Background
# 33                             Precuneous Cortex
# 34                          Middle Frontal Gyrus
# 35                                    Background
# 36                        Superior Frontal Gyrus
# 37                                    Background
# 38       Supramarginal Gyrus, posterior division
# 39                                    Background
# 40                                    Background
# 41                                    Background
# 42                                    Background
# 43                                    Background
# 44                                    Background
# 45                                    Background
# 46                        Superior Frontal Gyrus
# 47                                    Background
# 48                                  Frontal Pole
# 49     Parahippocampal Gyrus, posterior division
#
#     harvard_oxford_cortical_value harvard_oxford_subcortical_label  \
# 0                               0                       Background
# 1                               0                       Background
# 2                               0       Left Cerebral White Matter
# 3                              35             Left Cerebral Cortex
# 4                               0                       Brain-Stem
# 5                               3             Left Cerebral Cortex
# 6                               1             Left Cerebral Cortex
# 7                              20             Left Cerebral Cortex
# 8                               0       Left Cerebral White Matter
# 9                               2             Left Cerebral Cortex
# 10                              0       Left Cerebral White Matter
# 11                             44             Left Cerebral Cortex
# 12                             47            Right Cerebral Cortex
# 13                             48             Left Cerebral Cortex
# 14                             48             Left Cerebral Cortex
# 15                             48             Left Cerebral Cortex
# 16                              0      Right Cerebral White Matter
# 17                              0       Left Cerebral White Matter
# 18                             36            Right Cerebral Cortex
# 19                             36            Right Cerebral Cortex
# 20                              0            Right Cerebral Cortex
# 21                              0      Right Cerebral White Matter
# 22                              3            Right Cerebral Cortex
# 23                             22             Left Cerebral Cortex
# 24                             22             Left Cerebral Cortex
# 25                             13            Right Cerebral Cortex
# 26                             21            Right Cerebral Cortex
# 27                             36             Left Cerebral Cortex
# 28                             36             Left Cerebral Cortex
# 29                             28             Left Cerebral Cortex
# 30                             20             Left Cerebral Cortex
# 31                             31             Left Cerebral Cortex
# 32                              0                       Background
# 33                             31             Left Cerebral Cortex
# 34                              4             Left Cerebral Cortex
# 35                              0                       Background
# 36                              3            Right Cerebral Cortex
# 37                              0                       Brain-Stem
# 38                             20             Left Cerebral Cortex
# 39                              0                       Brain-Stem
# 40                              0                       Background
# 41                              0                       Background
# 42                              0                       Brain-Stem
# 43                              0                       Brain-Stem
# 44                              0                       Brain-Stem
# 45                              0                       Background
# 46                              3             Left Cerebral Cortex
# 47                              0                       Background
# 48                              1            Right Cerebral Cortex
# 49                             35             Left Cerebral Cortex
#
#     harvard_oxford_subcortical_value
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  2
# 4                                  8
# 5                                  2
# 6                                  2
# 7                                  2
# 8                                  1
# 9                                  2
# 10                                 1
# 11                                 2
# 12                                13
# 13                                 2
# 14                                 2
# 15                                 2
# 16                                12
# 17                                 1
# 18                                13
# 19                                13
# 20                                13
# 21                                12
# 22                                13
# 23                                 2
# 24                                 2
# 25                                13
# 26                                13
# 27                                 2
# 28                                 2
# 29                                 2
# 30                                 2
# 31                                 2
# 32                                 0
# 33                                 2
# 34                                 2
# 35                                 0
# 36                                13
# 37                                 8
# 38                                 2
# 39                                 8
# 40                                 0
# 41                                 0
# 42                                 8
# 43                                 8
# 44                                 8
# 45                                 0
# 46                                 2
# 47                                 0
# 48                                13
# 49                                 2
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_cluster_details_labeled_smoothed5mm.csv

# %% [markdown]
# ## Plot main POST relevance contrasts on the common mean T1w background
#
# The high-resolution mean T1w from Notebook 00 is passed directly as `bg_img`. We do **not** manually resample it to the z-map grid.

# %%
# ============================================================
# 11. Plot main POST relevance contrasts on mean T1w background
# ============================================================

main_contrasts = [
    "post_oldRel_gt_new",
    "post_oldIrrel_gt_new",
    "post_rel_gt_irrel",
    "post_irrel_gt_rel",
    "post_old_gt_new_avg",
]

plot_title_map = {
    "post_oldRel_gt_new": "POST relevant old > new",
    "post_oldIrrel_gt_new": "POST irrelevant old > new",
    "post_rel_gt_irrel": "POST relevant old > irrelevant old",
    "post_irrel_gt_rel": "POST irrelevant old > relevant old",
    "post_old_gt_new_avg": "POST old > new, relevance-averaged",
}

plot_index_rows = []

for contrast_name in main_contrasts:
    subset = cluster_details_labeled.query(
        "contrast == @contrast_name and threshold_label == 'z_gt_2.33'"
    ).copy()

    if len(subset) == 0:
        print("No z > 2.33 clusters for", contrast_name)
        continue

    top = subset.sort_values("Peak Stat", ascending=False).iloc[0]
    z_map_path = second_level_table.set_index("contrast").loc[contrast_name, "z_map_path"]
    cut_coords = (float(top["X"]), float(top["Y"]), float(top["Z"]))

    atlas_label = top.get("harvard_oxford_cortical_label", "")
    if atlas_label == "Background":
        atlas_label = top.get("harvard_oxford_subcortical_label", "Background")

    title = f"{plot_title_map[contrast_name]}\n{atlas_label}, peak z = {float(top['Peak Stat']):.2f}"
    fig_path = dirs["figures"] / f"{ANALYSIS_NAME}_{contrast_name}_top_peak_on_mean_T1w_{SMOOTHING_LABEL}.png"

    plot_group_stat_map(
        z_map_path=z_map_path,
        cut_coords=cut_coords,
        title=title,
        threshold=2.33,
        vmax=5.0,
        output_path=fig_path,
        bg_img=mean_t1w_img if USE_MEAN_T1W_BACKGROUND else None,
        dim=-0.2,
    )

    plot_index_rows.append({
        "contrast": contrast_name,
        "figure_path": str(fig_path),
        "x": cut_coords[0],
        "y": cut_coords[1],
        "z": cut_coords[2],
        "peak_z": float(top["Peak Stat"]),
        "atlas_label": atlas_label,
        "background": "mean_T1w" if USE_MEAN_T1W_BACKGROUND else "MNI_template",
    })

plot_index = pd.DataFrame(plot_index_rows)
plot_index_path = dirs["tables"] / f"{ANALYSIS_NAME}_figure_index_on_mean_T1w_{SMOOTHING_LABEL}.csv"
plot_index.to_csv(plot_index_path, index=False)

display(plot_index)
print("Saved:", plot_index_path)
# Out:
#                contrast  \
# 0    post_oldRel_gt_new
# 1  post_oldIrrel_gt_new
# 2     post_rel_gt_irrel
# 3     post_irrel_gt_rel
# 4   post_old_gt_new_avg
#
#                                                                                                                                                        figure_path  \
# 0  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/post_relevance_old_new_viewi...
# 1  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/post_relevance_old_new_viewi...
# 2  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/post_relevance_old_new_viewi...
# 3  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/post_relevance_old_new_viewi...
# 4  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/figures/post_relevance_old_new_viewi...
#
#       x     y     z    peak_z                                  atlas_label  \
# 0   4.0 -17.0 -18.0  4.063278                                   Background
# 1   6.5 -42.0 -35.5  3.998869                                   Brain-Stem
# 2   1.5 -47.0  42.0  4.301033                            Precuneous Cortex
# 3 -21.0  20.5  17.0  3.408719                   Left Cerebral White Matter
# 4 -18.5 -74.5  44.5  4.413140  Lateral Occipital Cortex, superior division
#
#   background
# 0   mean_T1w
# 1   mean_T1w
# 2   mean_T1w
# 3   mean_T1w
# 4   mean_T1w
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_figure_index_on_mean_T1w_smoothed5mm.csv

# %% [markdown]
# ## Optional interactive views
#
# These HTML views are useful for inspection but should not be the primary presentation figures.

# %%
# ============================================================
# 12. Save optional interactive views
# ============================================================

interactive_rows = []

for contrast_name in main_contrasts:
    z_map_path = second_level_table.set_index("contrast").loc[contrast_name, "z_map_path"]
    html_path = dirs["interactive"] / f"{ANALYSIS_NAME}_{contrast_name}_{SMOOTHING_LABEL}_interactive.html"
    view = make_interactive_view(z_map_path, threshold=2.33, title=plot_title_map[contrast_name])
    view.save_as_html(str(html_path))
    interactive_rows.append({"contrast": contrast_name, "interactive_html_path": str(html_path)})

interactive_index = pd.DataFrame(interactive_rows)
interactive_index_path = dirs["tables"] / f"{ANALYSIS_NAME}_interactive_index_{SMOOTHING_LABEL}.csv"
interactive_index.to_csv(interactive_index_path, index=False)

display(interactive_index)
print("Saved:", interactive_index_path)
# Out:
# /home/kroczak/.conda/envs/island/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kroczak/.conda/envs/island/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kroczak/.conda/envs/island/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kroczak/.conda/envs/island/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/kroczak/.conda/envs/island/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
#                contrast  \
# 0    post_oldRel_gt_new
# 1  post_oldIrrel_gt_new
# 2     post_rel_gt_irrel
# 3     post_irrel_gt_rel
# 4   post_old_gt_new_avg
#
#                                                                                                                                              interactive_html_path
# 0  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/interactive_views/post_relevance_old...
# 1  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/interactive_views/post_relevance_old...
# 2  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/interactive_views/post_relevance_old...
# 3  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/interactive_views/post_relevance_old...
# 4  /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/interactive_views/post_relevance_old...
# Saved: /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/tables/post_relevance_old_new_viewing_glm_interactive_index_smoothed5mm.csv

# %% [markdown]
# ## Notebook conclusion
#
# This notebook provides a structured POST-only relevance analysis.
#
# The key outputs are:
#
# - first-level POST relevance contrast maps for all N=27 subjects;
# - group-level maps for relevant old > new, irrelevant old > new, and relevant > irrelevant;
# - threshold summaries and cluster tables;
# - figures plotted on the common mean T1w background from Notebook 00.

# %%
# ============================================================
# 13. Save analysis manifest
# ============================================================

analysis_manifest = {
    "notebook": "05_post_relevance_old_new_viewing_glm.ipynb",
    "analysis_name": ANALYSIS_NAME,
    "project_root": str(PROJECT_ROOT),
    "n_subjects": len(subjects),
    "subjects": subjects,
    "smoothing_fwhm": SMOOTHING_FWHM,
    "smoothing_label": SMOOTHING_LABEL,
    "runtime_flags": {
        "RUN_FIRST_LEVEL": RUN_FIRST_LEVEL,
        "OVERWRITE_FIRST_LEVEL": OVERWRITE_FIRST_LEVEL,
        "RUN_SECOND_LEVEL": RUN_SECOND_LEVEL,
        "OVERWRITE_SECOND_LEVEL": OVERWRITE_SECOND_LEVEL,
        "USE_MEAN_T1W_BACKGROUND": USE_MEAN_T1W_BACKGROUND,
    },
    "main_contrasts": {
        name: contrast_specs[name]
        for name in [
            "post_oldRel_gt_new",
            "post_oldIrrel_gt_new",
            "post_rel_gt_irrel",
            "post_irrel_gt_rel",
            "post_old_gt_new_avg",
        ]
    },
    "key_outputs": {
        "contrast_definitions": str(contrast_table_path),
        "event_qc": str(event_qc_path),
        "all_events": str(all_events_path),
        "first_level_qc": str(first_level_qc_path),
        "first_level_contrast_qc": str(first_level_contrast_qc_path),
        "first_level_map_qc": str(map_qc_path),
        "second_level_table": str(second_level_table_path),
        "threshold_summary": str(threshold_summary_path),
        "cluster_summary": str(cluster_summary_path),
        "cluster_details": str(cluster_details_path),
        "cluster_details_labeled": str(cluster_details_labeled_path),
        "figure_index_on_mean_T1w": str(plot_index_path),
        "interactive_index": str(interactive_index_path),
        "mean_t1w_background": str(mean_t1w_path),
    },
}

analysis_manifest_path = dirs["restart"] / f"{ANALYSIS_NAME}_analysis_manifest.json"
with open(analysis_manifest_path, "w") as f:
    json.dump(analysis_manifest, f, indent=2)

print("Saved analysis manifest:")
print(analysis_manifest_path)
# Out:
# Saved analysis manifest:
# /media/RCPNAS/Data3/Alison_island/kroczak/island_semester_project/data/processed/glm/post_relevance_old_new_viewing_glm/restart/post_relevance_old_new_viewing_glm_analysis_manifest.json
